# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexsinator/Challenge_Alura_Store_Alex/blob/main/TelecomX_LATAM_Parte_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_csv('/content/datos_tratados.csv')

# %% [markdown]
# # Lectura de los datos

# %%
datos
# Out:
#       customerID Churn customer.gender customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                     No
# 1     0003-MKNFE    No            Male                     No
# 2     0004-TLHLJ   Yes            Male                     No
# 3     0011-IGKFF   Yes            Male                     Si
# 4     0013-EXCHZ   Yes          Female                     Si
# ...          ...   ...             ...                    ...
# 7038  9987-LUTYD    No          Female                     No
# 7039  9992-RRAMN   Yes            Male                     No
# 7040  9992-UJOEL    No            Male                     No
# 7041  9993-LHIEB    No            Male                     No
# 7042  9995-HOTOH    No            Male                     No
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# 1                  No                  No                9                Yes
# 2                  No                  No                4                Yes
# 3                 Yes                  No               13                Yes
# 4                 Yes                  No                3                Yes
# ...               ...                 ...              ...                ...
# 7038               No                  No               13                Yes
# 7039              Yes                  No               22                Yes
# 7040               No                  No                2                Yes
# 7041              Yes                 Yes               67                Yes
# 7042              Yes                 Yes               63                 No
#
#      phone.MultipleLines internet.InternetService  ...  \
# 0                     No                      DSL  ...
# 1                    Yes                      DSL  ...
# 2                     No              Fiber optic  ...
# 3                     No              Fiber optic  ...
# 4                     No              Fiber optic  ...
# ...                  ...                      ...  ...
# 7038                  No                      DSL  ...
# 7039                 Yes              Fiber optic  ...
# 7040                  No                      DSL  ...
# 7041                  No                      DSL  ...
# 7042    No phone service                      DSL  ...
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 0                           No                  Yes                  Yes
# 1                           No                   No                   No
# 2                          Yes                   No                   No
# 3                          Yes                   No                  Yes
# 4                           No                  Yes                  Yes
# ...                        ...                  ...                  ...
# 7038                        No                  Yes                   No
# 7039                        No                   No                   No
# 7040                        No                   No                   No
# 7041                       Yes                  Yes                   No
# 7042                       Yes                   No                  Yes
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 0                          No         One year                      Yes
# 1                         Yes   Month-to-month                       No
# 2                          No   Month-to-month                      Yes
# 3                         Yes   Month-to-month                      Yes
# 4                          No   Month-to-month                      Yes
# ...                       ...              ...                      ...
# 7038                       No         One year                       No
# 7039                      Yes   Month-to-month                      Yes
# 7040                       No   Month-to-month                      Yes
# 7041                      Yes         Two year                       No
# 7042                      Yes         Two year                       No
#
#      account.PaymentMethod account.Charges.Monthly account.Charges.Total  \
# 0             Mailed check                   65.60                593.30
# 1             Mailed check                   59.90                542.40
# 2         Electronic check                   73.90                280.85
# 3         Electronic check                   98.00               1237.85
# 4             Mailed check                   83.90                267.40
# ...                    ...                     ...                   ...
# 7038          Mailed check                   55.15                742.90
# 7039      Electronic check                   85.10               1873.70
# 7040          Mailed check                   50.30                 92.75
# 7041          Mailed check                   67.85               4627.65
# 7042      Electronic check                   59.00               3707.60
#
#       Cuentas_Diarias
# 0            2.186667
# 1            1.996667
# 2            2.463333
# 3            3.266667
# 4            2.796667
# ...               ...
# 7038         1.838333
# 7039         2.836667
# 7040         1.676667
# 7041         2.261667
# 7042         1.966667
#
# [7043 rows x 22 columns]

# %%
datos.shape
# Out:
# (7043, 22)

# %%
datos.describe()
# Out:
#        customer.tenure  account.Charges.Monthly  account.Charges.Total  \
# count      7043.000000              7043.000000            7032.000000
# mean         32.371149                64.761692            2283.300441
# std          24.559481                30.090047            2266.771362
# min           0.000000                18.250000              18.800000
# 25%           9.000000                35.500000             401.450000
# 50%          29.000000                70.350000            1397.475000
# 75%          55.000000                89.850000            3794.737500
# max          72.000000               118.750000            8684.800000
#
#        Cuentas_Diarias
# count      7043.000000
# mean          2.158723
# std           1.003002
# min           0.608333
# 25%           1.183333
# 50%           2.345000
# 75%           2.995000
# max           3.958333

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7043 non-null   object
#  1   Churn                      7043 non-null   object
#  2   customer.gender            7043 non-null   object
#  3   customer.SeniorCitizen     7043 non-null   object
#  4   customer.Partner           7043 non-null   object
#  5   customer.Dependents        7043 non-null   object
#  6   customer.tenure            7043 non-null   int64
#  7   phone.PhoneService         7043 non-null   object
#  8   phone.MultipleLines        7043 non-null   object
#  9   internet.InternetService   7043 non-null   object
#  10  internet.OnlineSecurity    7043 non-null   object
#  11  internet.OnlineBackup      7043 non-null   object
#  12  internet.DeviceProtection  7043 non-null   object
#  13  internet.TechSupport       7043 non-null   object
#  14  internet.StreamingTV       7043 non-null   object
#  15  internet.StreamingMovies   7043 non-null   object
#  16  account.Contract           7043 non-null   object
#  17  account.PaperlessBilling   7043 non-null   object
#  18  account.PaymentMethod      7043 non-null   object
#  19  account.Charges.Monthly    7043 non-null   float64
#  20  account.Charges.Total      7032 non-null   float64
#  21  Cuentas_Diarias            7043 non-null   float64
# dtypes: float64(3), int64(1), object(18)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Análisis de los datos

# %%
datos['phone.MultipleLines'].value_counts()
# Out:
# phone.MultipleLines
# No                  3390
# Yes                 2971
# No phone service     682
# Name: count, dtype: int64

# %%
datos['internet.InternetService'].value_counts()
# Out:
# internet.InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
datos['internet.OnlineSecurity'].value_counts()
# Out:
# internet.OnlineSecurity
# No                     3498
# Yes                    2019
# No internet service    1526
# Name: count, dtype: int64

# %%
datos['internet.OnlineBackup'].value_counts()
# Out:
# internet.OnlineBackup
# No                     3088
# Yes                    2429
# No internet service    1526
# Name: count, dtype: int64

# %%
datos['internet.DeviceProtection'].value_counts()
# Out:
# internet.DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %%
datos['internet.DeviceProtection'].value_counts()
# Out:
# internet.DeviceProtection
# No                     3095
# Yes                    2422
# No internet service    1526
# Name: count, dtype: int64

# %%
datos['internet.TechSupport'].value_counts()
# Out:
# internet.TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
datos['internet.TechSupport'].value_counts()
# Out:
# internet.TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
datos['internet.StreamingTV'].value_counts()
# Out:
# internet.StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
datos['internet.StreamingMovies'].value_counts()
# Out:
# internet.StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64

# %% [markdown]
# ### Revisión de consistencia de datos

# %%
columnas_a_verificar = ['internet.OnlineSecurity', 'internet.OnlineBackup', 'internet.DeviceProtection', 'internet.TechSupport', 'internet.StreamingTV', 'internet.StreamingMovies']
columna_referencia = 'internet.InternetService'

# %%
for columna in columnas_a_verificar:
    inconsistencias = (datos[columna_referencia] == 'Yes') & (datos[columna] == 'No internet service')
    if inconsistencias.any():
        print(f"Inconsistencias encontradas en la columna:  {columna}.")
    else:
        print(f"No se encontraron inconsistencias en la columna {columna}.")
# Out:
# No se encontraron inconsistencias en la columna internet.OnlineSecurity.
# No se encontraron inconsistencias en la columna internet.OnlineBackup.
# No se encontraron inconsistencias en la columna internet.DeviceProtection.
# No se encontraron inconsistencias en la columna internet.TechSupport.
# No se encontraron inconsistencias en la columna internet.StreamingTV.
# No se encontraron inconsistencias en la columna internet.StreamingMovies.

# %% [markdown]
# ##Tratamiento de los datos

# %%
datos.tail(10)
# Out:
#       customerID Churn customer.gender customer.SeniorCitizen  \
# 7033  9975-SKRNR    No            Male                     No
# 7034  9978-HYCIN    No            Male                     Si
# 7035  9979-RGMZT    No          Female                     No
# 7036  9985-MWVIX   Yes          Female                     No
# 7037  9986-BONCE   Yes          Female                     No
# 7038  9987-LUTYD    No          Female                     No
# 7039  9992-RRAMN   Yes            Male                     No
# 7040  9992-UJOEL    No            Male                     No
# 7041  9993-LHIEB    No            Male                     No
# 7042  9995-HOTOH    No            Male                     No
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 7033               No                  No                1                Yes
# 7034              Yes                 Yes               47                Yes
# 7035               No                  No                7                Yes
# 7036               No                  No                1                Yes
# 7037               No                  No                4                Yes
# 7038               No                  No               13                Yes
# 7039              Yes                  No               22                Yes
# 7040               No                  No                2                Yes
# 7041              Yes                 Yes               67                Yes
# 7042              Yes                 Yes               63                 No
#
#      phone.MultipleLines internet.InternetService  ...  \
# 7033                  No                       No  ...
# 7034                  No              Fiber optic  ...
# 7035                  No              Fiber optic  ...
# 7036                  No              Fiber optic  ...
# 7037                  No                       No  ...
# 7038                  No                      DSL  ...
# 7039                 Yes              Fiber optic  ...
# 7040                  No                      DSL  ...
# 7041                  No                      DSL  ...
# 7042    No phone service                      DSL  ...
#
#      internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 7033       No internet service  No internet service  No internet service
# 7034                        No                   No                  Yes
# 7035                        No                   No                  Yes
# 7036                        No                   No                   No
# 7037       No internet service  No internet service  No internet service
# 7038                        No                  Yes                   No
# 7039                        No                   No                   No
# 7040                        No                   No                   No
# 7041                       Yes                  Yes                   No
# 7042                       Yes                   No                  Yes
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 7033      No internet service   Month-to-month                       No
# 7034                       No         One year                      Yes
# 7035                      Yes         One year                      Yes
# 7036                       No   Month-to-month                      Yes
# 7037      No internet service   Month-to-month                       No
# 7038                       No         One year                       No
# 7039                      Yes   Month-to-month                      Yes
# 7040                       No   Month-to-month                      Yes
# 7041                      Yes         Two year                       No
# 7042                      Yes         Two year                       No
#
#           account.PaymentMethod account.Charges.Monthly account.Charges.Total  \
# 7033               Mailed check                   18.90                 18.90
# 7034  Bank transfer (automatic)                   84.95               4018.05
# 7035               Mailed check                   94.05                633.45
# 7036               Mailed check                   70.15                 70.15
# 7037  Bank transfer (automatic)                   20.95                 85.50
# 7038               Mailed check                   55.15                742.90
# 7039           Electronic check                   85.10               1873.70
# 7040               Mailed check                   50.30                 92.75
# 7041               Mailed check                   67.85               4627.65
# 7042           Electronic check                   59.00               3707.60
#
#       Cuentas_Diarias
# 7033         0.630000
# 7034         2.831667
# 7035         3.135000
# 7036         2.338333
# 7037         0.698333
# 7038         1.838333
# 7039         2.836667
# 7040         1.676667
# 7041         2.261667
# 7042         1.966667
#
# [10 rows x 22 columns]

# %%
datos = datos.drop('customerID', axis = 1)

# %%
# Codigo para no mostrar advertencias sobre el codigo
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Codificación de datos

# %%
# Reemplazos a binarios
datos['Churn'] = datos['Churn'].replace({'No': 0, 'Yes':1})
datos['customer.gender'] = datos['customer.gender'].replace({'Male': 0, 'Female': 1})
datos['customer.SeniorCitizen'] = datos['customer.SeniorCitizen'].replace({'No': 0, 'Si': 1})
datos['customer.Partner'] = datos['customer.Partner'].replace({'No': 0, 'Yes':1})
datos['customer.Dependents'] = datos['customer.Dependents'].replace({'No': 0, 'Yes':1})
datos['phone.PhoneService'] = datos['phone.PhoneService'].replace({'No': 0, 'Yes':1})
datos['account.PaperlessBilling'] = datos['account.PaperlessBilling'].replace({'No': 0, 'Yes':1})

# %%
datos.sample(10)
# Out:
#       Churn  customer.gender  customer.SeniorCitizen  customer.Partner  \
# 4056      1                0                       0                 0
# 2341      0                1                       1                 0
# 6979      0                1                       1                 0
# 4116      0                1                       0                 1
# 4051      1                0                       1                 0
# 2314      0                0                       0                 1
# 4303      0                0                       0                 1
# 4756      0                1                       0                 1
# 1659      1                1                       1                 0
# 899       0                0                       0                 0
#
#       customer.Dependents  customer.tenure  phone.PhoneService  \
# 4056                    0                2                   1
# 2341                    0               16                   1
# 6979                    0               65                   0
# 4116                    0               57                   1
# 4051                    0                9                   1
# 2314                    1               28                   0
# 4303                    1               23                   1
# 4756                    0               70                   1
# 1659                    0               10                   0
# 899                     0               24                   1
#
#      phone.MultipleLines internet.InternetService internet.OnlineSecurity  \
# 4056                  No              Fiber optic                      No
# 2341                 Yes                      DSL                     Yes
# 6979    No phone service                      DSL                      No
# 4116                  No                       No     No internet service
# 4051                 Yes                      DSL                     Yes
# 2314    No phone service                      DSL                     Yes
# 4303                  No                      DSL                     Yes
# 4756                  No                      DSL                     Yes
# 1659    No phone service                      DSL                      No
# 899                   No              Fiber optic                      No
#
#       ... internet.DeviceProtection internet.TechSupport internet.StreamingTV  \
# 4056  ...                       Yes                  Yes                   No
# 2341  ...                        No                   No                   No
# 6979  ...                       Yes                   No                  Yes
# 4116  ...       No internet service  No internet service  No internet service
# 4051  ...                        No                   No                   No
# 2314  ...                       Yes                  Yes                  Yes
# 4303  ...                        No                  Yes                   No
# 4756  ...                       Yes                  Yes                  Yes
# 1659  ...                        No                   No                   No
# 899   ...                       Yes                   No                   No
#
#      internet.StreamingMovies account.Contract account.PaperlessBilling  \
# 4056                       No   Month-to-month                        1
# 2341                       No   Month-to-month                        1
# 6979                      Yes         Two year                        1
# 4116      No internet service         Two year                        0
# 4051                       No   Month-to-month                        0
# 2314                       No         One year                        0
# 4303                       No         One year                        0
# 4756                      Yes         Two year                        0
# 1659                      Yes   Month-to-month                        1
# 899                       Yes   Month-to-month                        1
#
#           account.PaymentMethod account.Charges.Monthly  \
# 4056           Electronic check                   79.85
# 2341           Electronic check                   54.10
# 6979  Bank transfer (automatic)                   53.50
# 4116  Bank transfer (automatic)                   19.90
# 4051           Electronic check                   54.55
# 2314               Mailed check                   50.80
# 4303    Credit card (automatic)                   57.20
# 4756    Credit card (automatic)                   86.45
# 1659           Electronic check                   34.70
# 899            Electronic check                   89.55
#
#       account.Charges.Total  Cuentas_Diarias
# 4056                 152.45         2.661667
# 2341                 889.00         1.803333
# 6979                3517.90         1.783333
# 4116                1115.60         0.663333
# 4051                 494.05         1.818333
# 2314                1386.80         1.693333
# 4303                1423.35         1.906667
# 4756                5950.20         2.881667
# 1659                 329.80         1.156667
# 899                 2187.15         2.985000
#
# [10 rows x 21 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      7043 non-null   int64
#  1   customer.gender            7043 non-null   int64
#  2   customer.SeniorCitizen     7043 non-null   int64
#  3   customer.Partner           7043 non-null   int64
#  4   customer.Dependents        7043 non-null   int64
#  5   customer.tenure            7043 non-null   int64
#  6   phone.PhoneService         7043 non-null   int64
#  7   phone.MultipleLines        7043 non-null   object
#  8   internet.InternetService   7043 non-null   object
#  9   internet.OnlineSecurity    7043 non-null   object
#  10  internet.OnlineBackup      7043 non-null   object
#  11  internet.DeviceProtection  7043 non-null   object
#  12  internet.TechSupport       7043 non-null   object
#  13  internet.StreamingTV       7043 non-null   object
#  14  internet.StreamingMovies   7043 non-null   object
#  15  account.Contract           7043 non-null   object
#  16  account.PaperlessBilling   7043 non-null   int64
#  17  account.PaymentMethod      7043 non-null   object
#  18  account.Charges.Monthly    7043 non-null   float64
#  19  account.Charges.Total      7032 non-null   float64
#  20  Cuentas_Diarias            7043 non-null   float64
# dtypes: float64(3), int64(8), object(10)
# memory usage: 1.1+ MB

# %%
# Hacer categoricas a númericas
categoricas = ['account.PaymentMethod', 'phone.MultipleLines', 'internet.InternetService', 'internet.OnlineSecurity',
               'internet.OnlineBackup', 'internet.DeviceProtection', 'internet.TechSupport', 'internet.StreamingTV',
               'internet.StreamingMovies', 'account.Contract']

# %%
datos_codificados = pd.get_dummies(datos, columns=categoricas, dtype = int)

# %%
datos_codificados.sample(10)
# Out:
#       Churn  customer.gender  customer.SeniorCitizen  customer.Partner  \
# 860       0                0                       0                 1
# 2840      0                1                       0                 1
# 4490      0                1                       0                 0
# 4110      1                0                       1                 0
# 6447      0                1                       0                 0
# 631       1                0                       0                 0
# 1696      1                0                       1                 1
# 6162      0                0                       0                 0
# 1128      0                0                       0                 1
# 4302      0                1                       0                 0
#
#       customer.Dependents  customer.tenure  phone.PhoneService  \
# 860                     1               52                   1
# 2840                    0               64                   1
# 4490                    0               13                   0
# 4110                    0               33                   1
# 6447                    0               59                   1
# 631                     0                7                   1
# 1696                    0               40                   1
# 6162                    0               41                   1
# 1128                    0               53                   1
# 4302                    0               25                   1
#
#       account.PaperlessBilling  account.Charges.Monthly  \
# 860                          0                    24.80
# 2840                         1                    99.00
# 4490                         1                    31.65
# 4110                         1                    83.85
# 6447                         0                    95.80
# 631                          0                    74.65
# 1696                         0                   101.85
# 6162                         1                    74.25
# 1128                         0                    19.90
# 4302                         0                    19.90
#
#       account.Charges.Total  ...  internet.TechSupport_Yes  \
# 860                 1229.10  ...                         0
# 2840                6375.80  ...                         0
# 4490                 389.95  ...                         0
# 4110                2716.30  ...                         0
# 6447                5655.45  ...                         0
# 631                  544.55  ...                         0
# 1696                4086.30  ...                         0
# 6162                3089.10  ...                         1
# 1128                1110.05  ...                         0
# 4302                 527.50  ...                         0
#
#       internet.StreamingTV_No  internet.StreamingTV_No internet service  \
# 860                         0                                         1
# 2840                        0                                         0
# 4490                        1                                         0
# 4110                        1                                         0
# 6447                        0                                         0
# 631                         1                                         0
# 1696                        0                                         0
# 6162                        1                                         0
# 1128                        0                                         1
# 4302                        0                                         1
#
#       internet.StreamingTV_Yes  internet.StreamingMovies_No  \
# 860                          0                            0
# 2840                         1                            0
# 4490                         0                            1
# 4110                         0                            1
# 6447                         1                            0
# 631                          0                            1
# 1696                         1                            0
# 6162                         0                            1
# 1128                         0                            0
# 4302                         0                            0
#
#       internet.StreamingMovies_No internet service  \
# 860                                              1
# 2840                                             0
# 4490                                             0
# 4110                                             0
# 6447                                             0
# 631                                              0
# 1696                                             0
# 6162                                             0
# 1128                                             1
# 4302                                             1
#
#       internet.StreamingMovies_Yes  account.Contract_Month-to-month  \
# 860                              0                                0
# 2840                             1                                0
# 4490                             0                                1
# 4110                             0                                1
# 6447                             1                                0
# 631                              0                                1
# 1696                             1                                1
# 6162                             0                                1
# 1128                             0                                0
# 4302                             0                                0
#
#       account.Contract_One year  account.Contract_Two year
# 860                           0                          1
# 2840                          0                          1
# 4490                          0                          0
# 4110                          0                          0
# 6447                          0                          1
# 631                           0                          0
# 1696                          0                          0
# 6162                          0                          0
# 1128                          0                          1
# 4302                          1                          0
#
# [10 rows x 42 columns]

# %%
datos_codificados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 42 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Churn                                            7043 non-null   int64
#  1   customer.gender                                  7043 non-null   int64
#  2   customer.SeniorCitizen                           7043 non-null   int64
#  3   customer.Partner                                 7043 non-null   int64
#  4   customer.Dependents                              7043 non-null   int64
#  5   customer.tenure                                  7043 non-null   int64
#  6   phone.PhoneService                               7043 non-null   int64
#  7   account.PaperlessBilling                         7043 non-null   int64
#  8   account.Charges.Monthly                          7043 non-null   float64
#  9   account.Charges.Total                            7032 non-null   float64
#  10  Cuentas_Diarias                                  7043 non-null   float64
#  11  account.PaymentMethod_Bank transfer (automatic)  7043 non-null   int64
#  12  account.PaymentMethod_Credit card (automatic)    7043 non-null   int64
#  13  account.PaymentMethod_Electronic check           7043 non-null   int64
#  14  account.PaymentMethod_Mailed check               7043 non-null   int64
#  15  phone.MultipleLines_No                           7043 non-null   int64
#  16  phone.MultipleLines_No phone service             7043 non-null   int64
#  17  phone.MultipleLines_Yes                          7043 non-null   int64
#  18  internet.InternetService_DSL                     7043 non-null   int64
#  19  internet.InternetService_Fiber optic             7043 non-null   int64
#  20  internet.InternetService_No                      7043 non-null   int64
#  21  internet.OnlineSecurity_No                       7043 non-null   int64
#  22  internet.OnlineSecurity_No internet service      7043 non-null   int64
#  23  internet.OnlineSecurity_Yes                      7043 non-null   int64
#  24  internet.OnlineBackup_No                         7043 non-null   int64
#  25  internet.OnlineBackup_No internet service        7043 non-null   int64
#  26  internet.OnlineBackup_Yes                        7043 non-null   int64
#  27  internet.DeviceProtection_No                     7043 non-null   int64
#  28  internet.DeviceProtection_No internet service    7043 non-null   int64
#  29  internet.DeviceProtection_Yes                    7043 non-null   int64
#  30  internet.TechSupport_No                          7043 non-null   int64
#  31  internet.TechSupport_No internet service         7043 non-null   int64
#  32  internet.TechSupport_Yes                         7043 non-null   int64
#  33  internet.StreamingTV_No                          7043 non-null   int64
#  34  internet.StreamingTV_No internet service         7043 non-null   int64
#  35  internet.StreamingTV_Yes                         7043 non-null   int64
#  36  internet.StreamingMovies_No                      7043 non-null   int64
#  37  internet.StreamingMovies_No internet service     7043 non-null   int64
#  38  internet.StreamingMovies_Yes                     7043 non-null   int64
#  39  account.Contract_Month-to-month                  7043 non-null   int64
#  40  account.Contract_One year                        7043 non-null   int64
#  41  account.Contract_Two year                        7043 non-null   int64
# dtypes: float64(3), int64(39)
# memory usage: 2.3 MB

# %%
datos['Churn'].value_counts(normalize = True) * 100
# Out:
# Churn
# 0    73.463013
# 1    26.536987
# Name: proportion, dtype: float64

# %%
df = datos_codificados
df.sample(10)
# Out:
#       Churn  customer.gender  customer.SeniorCitizen  customer.Partner  \
# 1490      1                1                       0                 1
# 2794      0                0                       0                 0
# 2188      0                1                       0                 0
# 5212      1                1                       0                 0
# 4332      0                1                       0                 0
# 5711      0                0                       0                 1
# 5798      0                0                       0                 1
# 4268      0                0                       0                 1
# 597       1                1                       0                 0
# 1039      1                1                       0                 0
#
#       customer.Dependents  customer.tenure  phone.PhoneService  \
# 1490                    0               47                   1
# 2794                    0               72                   1
# 2188                    0               63                   1
# 5212                    0                5                   1
# 4332                    0               29                   0
# 5711                    1               12                   1
# 5798                    1               66                   0
# 4268                    0               70                   1
# 597                     0                9                   1
# 1039                    0               58                   1
#
#       account.PaperlessBilling  account.Charges.Monthly  \
# 1490                         1                    85.30
# 2794                         0                    19.30
# 2188                         0                    98.00
# 5212                         1                    90.80
# 4332                         0                    39.50
# 5711                         1                    21.15
# 5798                         1                    56.75
# 4268                         0                    25.15
# 597                          1                    79.55
# 1039                         1                   106.45
#
#       account.Charges.Total  ...  internet.TechSupport_Yes  \
# 1490                4045.65  ...                         0
# 2794                1414.80  ...                         0
# 2188                6218.45  ...                         0
# 5212                 455.50  ...                         0
# 4332                1082.75  ...                         1
# 5711                 306.05  ...                         0
# 5798                3708.40  ...                         0
# 4268                1940.85  ...                         0
# 597                  723.40  ...                         0
# 1039                6145.85  ...                         0
#
#       internet.StreamingTV_No  internet.StreamingTV_No internet service  \
# 1490                        1                                         0
# 2794                        0                                         1
# 2188                        0                                         0
# 5212                        0                                         0
# 4332                        1                                         0
# 5711                        0                                         1
# 5798                        0                                         0
# 4268                        0                                         1
# 597                         1                                         0
# 1039                        0                                         0
#
#       internet.StreamingTV_Yes  internet.StreamingMovies_No  \
# 1490                         0                            0
# 2794                         0                            0
# 2188                         1                            1
# 5212                         1                            1
# 4332                         0                            1
# 5711                         0                            0
# 5798                         1                            0
# 4268                         0                            0
# 597                          0                            0
# 1039                         1                            0
#
#       internet.StreamingMovies_No internet service  \
# 1490                                             0
# 2794                                             1
# 2188                                             0
# 5212                                             0
# 4332                                             0
# 5711                                             1
# 5798                                             0
# 4268                                             1
# 597                                              0
# 1039                                             0
#
#       internet.StreamingMovies_Yes  account.Contract_Month-to-month  \
# 1490                             1                                1
# 2794                             0                                0
# 2188                             0                                0
# 5212                             0                                1
# 4332                             0                                0
# 5711                             0                                1
# 5798                             1                                0
# 4268                             0                                0
# 597                              1                                1
# 1039                             1                                0
#
#       account.Contract_One year  account.Contract_Two year
# 1490                          0                          0
# 2794                          0                          1
# 2188                          0                          1
# 5212                          0                          0
# 4332                          1                          0
# 5711                          0                          0
# 5798                          0                          1
# 4268                          0                          1
# 597                           0                          0
# 1039                          1                          0
#
# [10 rows x 42 columns]

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# account.Charges.Total                              11
# Churn                                               0
# customer.gender                                     0
# customer.SeniorCitizen                              0
# customer.Dependents                                 0
# customer.Partner                                    0
# customer.tenure                                     0
# phone.PhoneService                                  0
# account.PaperlessBilling                            0
# account.Charges.Monthly                             0
# Cuentas_Diarias                                     0
# account.PaymentMethod_Bank transfer (automatic)     0
# account.PaymentMethod_Credit card (automatic)       0
# account.PaymentMethod_Electronic check              0
# account.PaymentMethod_Mailed check                  0
# phone.MultipleLines_No                              0
# phone.MultipleLines_No phone service                0
# phone.MultipleLines_Yes                             0
# internet.InternetService_DSL                        0
# internet.InternetService_Fiber optic                0
# internet.InternetService_No                         0
# internet.OnlineSecurity_No                          0
# internet.OnlineSecurity_No internet service         0
# internet.OnlineSecurity_Yes                         0
# internet.OnlineBackup_No                            0
# internet.OnlineBackup_No internet service           0
# internet.OnlineBackup_Yes                           0
# internet.DeviceProtection_No                        0
# internet.DeviceProtection_No internet service       0
# internet.DeviceProtection_Yes                       0
# internet.TechSupport_No                             0
# internet.TechSupport_No internet service            0
# internet.TechSupport_Yes                            0
# internet.StreamingTV_No                             0
# internet.StreamingTV_No internet service            0
# internet.StreamingTV_Yes                            0
# internet.StreamingMovies_No                         0
# internet.StreamingMovies_No internet service        0
# internet.StreamingMovies_Yes                        0
# account.Contract_Month-to-month                     0
# account.Contract_One year                           0
# account.Contract_Two year                           0
# dtype: int64

# %%
df = df.dropna(subset=['account.Charges.Total'])

# %% [markdown]
# ### Train y Test

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['Churn'], axis =1)
y = df['Churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
print('Conteo de clases en y_train')
print(y_train.value_counts())

print('\nProporción de clases en y_train')
print(y_train.value_counts(normalize= True))
# Out:
# Conteo de clases en y_train
# Churn
# 0    4143
# 1    1482
# Name: count, dtype: int64
#
# Proporción de clases en y_train
# Churn
# 0    0.736533
# 1    0.263467
# Name: proportion, dtype: float64

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# Churn                                              0
# customer.gender                                    0
# customer.SeniorCitizen                             0
# customer.Partner                                   0
# customer.Dependents                                0
# customer.tenure                                    0
# phone.PhoneService                                 0
# account.PaperlessBilling                           0
# account.Charges.Monthly                            0
# account.Charges.Total                              0
# Cuentas_Diarias                                    0
# account.PaymentMethod_Bank transfer (automatic)    0
# account.PaymentMethod_Credit card (automatic)      0
# account.PaymentMethod_Electronic check             0
# account.PaymentMethod_Mailed check                 0
# phone.MultipleLines_No                             0
# phone.MultipleLines_No phone service               0
# phone.MultipleLines_Yes                            0
# internet.InternetService_DSL                       0
# internet.InternetService_Fiber optic               0
# internet.InternetService_No                        0
# internet.OnlineSecurity_No                         0
# internet.OnlineSecurity_No internet service        0
# internet.OnlineSecurity_Yes                        0
# internet.OnlineBackup_No                           0
# internet.OnlineBackup_No internet service          0
# internet.OnlineBackup_Yes                          0
# internet.DeviceProtection_No                       0
# internet.DeviceProtection_No internet service      0
# internet.DeviceProtection_Yes                      0
# internet.TechSupport_No                            0
# internet.TechSupport_No internet service           0
# internet.TechSupport_Yes                           0
# internet.StreamingTV_No                            0
# internet.StreamingTV_No internet service           0
# internet.StreamingTV_Yes                           0
# internet.StreamingMovies_No                        0
# internet.StreamingMovies_No internet service       0
# internet.StreamingMovies_Yes                       0
# account.Contract_Month-to-month                    0
# account.Contract_One year                          0
# account.Contract_Two year                          0
# dtype: int64

# %%
df.shape
# Out:
# (7032, 42)

# %%
df.max()
# Out:
# Churn                                                 1.000000
# customer.gender                                       1.000000
# customer.SeniorCitizen                                1.000000
# customer.Partner                                      1.000000
# customer.Dependents                                   1.000000
# customer.tenure                                      72.000000
# phone.PhoneService                                    1.000000
# account.PaperlessBilling                              1.000000
# account.Charges.Monthly                             118.750000
# account.Charges.Total                              8684.800000
# Cuentas_Diarias                                       3.958333
# account.PaymentMethod_Bank transfer (automatic)       1.000000
# account.PaymentMethod_Credit card (automatic)         1.000000
# account.PaymentMethod_Electronic check                1.000000
# account.PaymentMethod_Mailed check                    1.000000
# phone.MultipleLines_No                                1.000000
# phone.MultipleLines_No phone service                  1.000000
# phone.MultipleLines_Yes                               1.000000
# internet.InternetService_DSL                          1.000000
# internet.InternetService_Fiber optic                  1.000000
# internet.InternetService_No                           1.000000
# internet.OnlineSecurity_No                            1.000000
# internet.OnlineSecurity_No internet service           1.000000
# internet.OnlineSecurity_Yes                           1.000000
# internet.OnlineBackup_No                              1.000000
# internet.OnlineBackup_No internet service             1.000000
# internet.OnlineBackup_Yes                             1.000000
# internet.DeviceProtection_No                          1.000000
# internet.DeviceProtection_No internet service         1.000000
# internet.DeviceProtection_Yes                         1.000000
# internet.TechSupport_No                               1.000000
# internet.TechSupport_No internet service              1.000000
# internet.TechSupport_Yes                              1.000000
# internet.StreamingTV_No                               1.000000
# internet.StreamingTV_No internet service              1.000000
# internet.StreamingTV_Yes                              1.000000
# internet.StreamingMovies_No                           1.000000
# internet.StreamingMovies_No internet service          1.000000
# internet.StreamingMovies_Yes                          1.000000
# account.Contract_Month-to-month                       1.000000
# account.Contract_One year                             1.000000
# account.Contract_Two year                             1.000000
# dtype: float64

# %% [markdown]
# ### Escalado de valores

# %%
columnas_valores_altos = ['customer.tenure', 'account.Charges.Monthly', 'account.Charges.Total', 'Cuentas_Diarias']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_escalado = scaler.fit_transform(X_train[columnas_valores_altos])

X_test_escalado = scaler.transform(X_test[columnas_valores_altos])

# %%
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()

X_train_scaled.loc[:,columnas_valores_altos] = X_train_escalado
X_test_scaled.loc[:,columnas_valores_altos] = X_test_escalado

# %% [markdown]
# ### SMOTE

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

Counter((y_train))
# Out:
# Counter({0: 4143, 1: 1482})

# %%
smote = SMOTE (random_state=50)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)

Counter((y_train_smote))
# Out:
# Counter({0: 4143, 1: 4143})
